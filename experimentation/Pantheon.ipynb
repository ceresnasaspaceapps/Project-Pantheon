# %% [markdown]
# # **Project Pantheon**
#
# **¿What's Pantheon?**
#
# **Education** is the foundation of every prosperous society, yet our current system is mired in stagnation and a lack of innovation. It's time for a profound change, a revolution that transforms the way students learn and engage with knowledge.
#
# Pantheon is our answer to this need. Inspired by the ancient Roman temple dedicated to all the gods, Pantheon stands as a **system of worlds of knowledge, where each world represents a key academic discipline**. For instance, Ceres, the Roman goddess of agriculture, symbolizes the world of biology, while Apollo, the Greek god of the sun, represents physics and astronomy. In Pantheon, each subject comes to life through iconic figures, creating a symbolic and emotional connection with learning.
#
# But our vision extends beyond mere aesthetic change. We firmly believe that education must be engaging to capture the innate curiosity of younger students and simultaneously enhance their performance. That's why we've integrated **gamification** throughout Pantheon, where learning becomes an interactive adventure filled with challenges, achievements, and rewards.
#
# The **reliability of knowledge** is crucial, and at Pantheon, we ensure it through a smart chatbot designed to resolve queries in real time. This assistant does not merely answer general questions but also **extracts responses directly from the materials provided by teachers** using an intuitive "drag and drop" feature. Thus, every query is addressed with precision and relevance.
#
# Moreover, we harness the power of the most advanced generative intelligence. For example, a student can upload a photo of a plant, and Pantheon will provide detailed information about its species, potential diseases, and care tips. This is just one of many examples of how technology can transform the way students interact with knowledge in a practical and enriching manner.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ## **Examples of data management**

# %% [markdown]
# # **Interactive Map** <a id="interactive-map"></a>
# ### The interactive map enables users to register their plants, explore plant data in their local area, and monitor which cities or regions lead in "green impact," measured by the number of plants and the quality of their care. By integrating the open-source [OpenWeather API](https://openweathermap.org/api), **we can also monitor real-time environmental data** such as air quality, rainfall, temperature, humidity, and cloud cover.
#
# ### When the user clicks on the map, it expands, allowing them to interact with their class in a dynamic and engaging way.

# %% [markdown]
# ![LeaderBoard.png](data:image/png;base64,...)

# %%
# !pip install folium

# %% [markdown]
# **Synthetic data**
#
# Due to time constraints during the hackathon, we were unable to utilize real data. Consequently, we opted to generate synthetic data.

# %%
locations = [
    # Málaga ciudad
    {'name': 'Plants of Chen Wei', 'lat': 36.7213, 'lon': -4.4216, 'impact': 9, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Hiroshi Sato', 'lat': 36.7223, 'lon': -4.4251, 'impact': 8, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Ji-ho Park', 'lat': 36.7153, 'lon': -4.4201, 'impact': 7, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Zhang Li', 'lat': 36.7196, 'lon': -4.4145, 'impact': 2, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Maria García', 'lat': 36.7202, 'lon': -4.4289, 'impact': 6, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Raj Patel', 'lat': 36.7235, 'lon': -4.4179, 'impact': 7, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Adebayo Okoro', 'lat': 36.7198, 'lon': -4.4317, 'impact': 8, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Fatima Khalid', 'lat': 36.7169, 'lon': -4.4243, 'impact': 7, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Pierre Dupont', 'lat': 36.7229, 'lon': -4.4205, 'impact': 6, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Thiago Silva', 'lat': 36.7185, 'lon': -4.4187, 'impact': 1, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Carmen López', 'lat': 36.7227, 'lon': -4.4168, 'impact': 7, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Ahmed Hassan', 'lat': 36.7200, 'lon': -4.4261, 'impact': 3, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Vladimir Petrov', 'lat': 36.7231, 'lon': -4.4140, 'impact': 6, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Anna Müller', 'lat': 36.7170, 'lon': -4.4225, 'impact': 9, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Pablo Fernández', 'lat': 36.7250, 'lon': -4.4195, 'impact': 9, 'location': 'Málaga, Spain'},
    {'name': 'Plants of José Martínez', 'lat': 36.7213, 'lon': -4.4216, 'impact': 9, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Carmen Rodríguez', 'lat': 36.7223, 'lon': -4.4251, 'impact': 8, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Antonio Sánchez', 'lat': 36.7153, 'lon': -4.4201, 'impact': 7, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Lucía García', 'lat': 36.7196, 'lon': -4.4145, 'impact': 6, 'location': 'Málaga, Spain'},
    {'name': 'Plants of María González', 'lat': 36.7202, 'lon': -4.4289, 'impact': 6, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Francisco López', 'lat': 36.7235, 'lon': -4.4179, 'impact': 7, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Laura Fernández', 'lat': 36.7198, 'lon': -4.4317, 'impact': 9, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Javier Jiménez', 'lat': 36.7169, 'lon': -4.4243, 'impact': 5, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Beatriz Ruiz', 'lat': 36.7229, 'lon': -4.4205, 'impact': 8, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Daniel Pérez', 'lat': 36.7185, 'lon': -4.4187, 'impact': 6, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Marta Moreno', 'lat': 36.7227, 'lon': -4.4168, 'impact': 7, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Juan Torres', 'lat': 36.7200, 'lon': -4.4261, 'impact': 4, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Raquel Castro', 'lat': 36.7231, 'lon': -4.4140, 'impact': 5, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Pablo Romero', 'lat': 36.7170, 'lon': -4.4225, 'impact': 6, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Sara Ortiz', 'lat': 36.7250, 'lon': -4.4195, 'impact': 7, 'location': 'Málaga, Spain'},
    {'name': 'Plants of José Martínez', 'lat': 36.7183, 'lon': -4.4217, 'impact': 10, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Carmen Rodríguez', 'lat': 36.7215, 'lon': -4.4300, 'impact': 6, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Antonio Sánchez', 'lat': 36.7250, 'lon': -4.4341, 'impact': 8, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Lucía Fernández', 'lat': 36.7201, 'lon': -4.4190, 'impact': 9, 'location': 'Málaga, Spain'},
    {'name': 'Plants of María Gómez', 'lat': 36.7192, 'lon': -4.4255, 'impact': 5, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Francisco García', 'lat': 36.7220, 'lon': -4.4155, 'impact': 7, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Laura Jiménez', 'lat': 36.7142, 'lon': -4.4280, 'impact': 8, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Javier López', 'lat': 36.7235, 'lon': -4.4330, 'impact': 9, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Raquel Torres', 'lat': 36.7260, 'lon': -4.4192, 'impact': 4, 'location': 'Málaga, Spain'},
    {'name': 'Plants of David Moreno', 'lat': 36.7160, 'lon': -4.4240, 'impact': 6, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Beatriz Ruiz', 'lat': 36.7190, 'lon': -4.4305, 'impact': 9, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Daniel Pérez', 'lat': 36.7175, 'lon': -4.4185, 'impact': 7, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Marta Romero', 'lat': 36.7205, 'lon': -4.4170, 'impact': 8, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Juan Torres', 'lat': 36.7280, 'lon': -4.4255, 'impact': 5, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Inés Sánchez', 'lat': 36.7300, 'lon': -4.4315, 'impact': 10, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Manuel Castillo', 'lat': 36.7272, 'lon': -4.4127, 'impact': 6, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Alicia Medina', 'lat': 36.7130, 'lon': -4.4222, 'impact': 7, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Andrés Molina', 'lat': 36.7203, 'lon': -4.4230, 'impact': 9, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Carlos Navarro', 'lat': 36.7162, 'lon': -4.4295, 'impact': 5, 'location': 'Málaga, Spain'},
    {'name': 'Plants of Pilar Suárez', 'lat': 36.7218, 'lon': -4.4167, 'impact': 8, 'location': 'Málaga, Spain'},

    # Pueblos cercanos: Rincón de la Victoria, Torremolinos, Alhaurín de la Torre
    {'name': 'Plants of Juan Antonio Ruiz', 'lat': 36.7175, 'lon': -4.2788, 'impact': 8, 'location': 'Rincón de la Victoria, Spain'},
    {'name': 'Plants of Laura Vázquez', 'lat': 36.7146, 'lon': -4.2700, 'impact': 7, 'location': 'Rincón de la Victoria, Spain'},
    {'name': 'Plants of Francisco Herrera', 'lat': 36.6254, 'lon': -4.4995, 'impact': 7, 'location': 'Torremolinos, Spain'},
    {'name': 'Plants of Ana Martín', 'lat': 36.6204, 'lon': -4.4993, 'impact': 8, 'location': 'Torremolinos, Spain'},
    {'name': 'Plants of David Ortega', 'lat': 36.6614, 'lon': -4.5747, 'impact': 6, 'location': 'Alhaurín de la Torre, Spain'},
    {'name': 'Plants of Rosa García', 'lat': 36.6609, 'lon': -4.5637, 'impact': 9, 'location': 'Alhaurín de la Torre, Spain'},
    {'name': 'Plants of José Luis Moreno', 'lat': 36.6640, 'lon': -4.5779, 'impact': 5, 'location': 'Alhaurín de la Torre, Spain'},
    {'name': 'Plants of Silvia Marín', 'lat': 36.6630, 'lon': -4.5610, 'impact': 8, 'location': 'Alhaurín de la Torre, Spain'},
    {'name': 'Plants of Enrique León', 'lat': 36.7155, 'lon': -4.2788, 'impact': 7, 'location': 'Rincón de la Victoria, Spain'},
    {'name': 'Plants of Alba López', 'lat': 36.6209, 'lon': -4.4987, 'impact': 6, 'location': 'Torremolinos, Spain'},
    {'name': 'Plants of Juan Antonio Ruiz', 'lat': 36.7175, 'lon': -4.2788, 'impact': 9, 'location': 'Rincón de la Victoria, Spain'},
    {'name': 'Plants of Laura Vázquez', 'lat': 36.7146, 'lon': -4.2700, 'impact': 6, 'location': 'Rincón de la Victoria, Spain'},
    {'name': 'Plants of Francisco Herrera', 'lat': 36.6254, 'lon': -4.4995, 'impact': 7, 'location': 'Torremolinos, Spain'},
    {'name': 'Plants of Ana Martín', 'lat': 36.6204, 'lon': -4.4993, 'impact': 10, 'location': 'Torremolinos, Spain'},
    {'name': 'Plants of David Ortega', 'lat': 36.6614, 'lon': -4.5747, 'impact': 5, 'location': 'Alhaurín de la Torre, Spain'},
    {'name': 'Plants of Rosa García', 'lat': 36.6609, 'lon': -4.5637, 'impact': 9, 'location': 'Alhaurín de la Torre, Spain'},
    {'name': 'Plants of José Luis Moreno', 'lat': 36.6640, 'lon': -4.5779, 'impact': 6, 'location': 'Alhaurín de la Torre, Spain'},
    {'name': 'Plants of Silvia Marín', 'lat': 36.6630, 'lon': -4.5610, 'impact': 8, 'location': 'Alhaurín de la Torre, Spain'},
    {'name': 'Plants of Enrique León', 'lat': 36.7155, 'lon': -4.2788, 'impact': 7, 'location': 'Rincón de la Victoria, Spain'},
    {'name': 'Plants of Alba López', 'lat': 36.6209, 'lon': -4.4987, 'impact': 6, 'location': 'Torremolinos, Spain'}

]

# %% [markdown]
# # **Map Generator**

# %%
import folium
from folium.plugins import HeatMap
import requests
from collections import defaultdict

api_key = "cfc9efc1d0f159518f7c843fa92a0635"

def get_air_quality(lat, lon):
    url = f"http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={api_key}"
    response = requests.get(url)
    return response.json()['list'][0]['components']

def get_rain(lat, lon):
    url = f"http://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={api_key}"
    response = requests.get(url)
    return response.json().get('rain', {}).get('1h', 0)

def get_current_weather(lat, lon):
    url = f"http://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={api_key}"
    response = requests.get(url)
    data = response.json()
    return {
        'description': data['weather'][0]['description'],
        'temp': data['main']['temp'] - 273.15,
        'humidity': data['main']['humidity'],
        'clouds': data['clouds']['all']
    }

def icon_size(impact):
    base_size = 20
    scale_factor = 4
    return (int(base_size + scale_factor * impact), int(base_size + scale_factor * impact))

def student_contributions(locations):
    student_impact = defaultdict(float)
    for location in locations:
        student = location['name'].split(",")[0].strip()  # Use the student's name
        student_impact[student] += location['impact']
    return sorted(student_impact.items(), key=lambda x: x[1], reverse=True)

my_map = folium.Map(location=[36.7250, -4.4195], zoom_start=14)
icon_url = "https://cdn-icons-png.flaticon.com/512/4778/4778362.png"

for location in locations:
    air_quality = get_air_quality(location['lat'], location['lon'])
    rain = get_rain(location['lat'], location['lon'])
    weather = get_current_weather(location['lat'], location['lon'])
    size = icon_size(location['impact'])

    icon = folium.CustomIcon(
        icon_image=icon_url,
        icon_size=size,
        icon_anchor=(size[0]//2, size[1])
    )

    popup_html = f"""
    <div style="font-size: 12px; width: 150px;">
    <strong>{location['name']}</strong><br>
    Air Quality AQI PM2.5: {air_quality['pm2_5']} µg/m³<br>
    Rain: {rain} mm/h<br>
    Weather: {weather['description']}<br>
    Temp: {weather['temp']:.2f}°C<br>
    Humidity: {weather['humidity']}%<br>
    Cloudiness: {weather['clouds']}%<br>
    Trees planted: {location['impact']}
    </div>
    """

    folium.Marker(
        location=[location['lat'], location['lon']],
        popup=folium.Popup(popup_html, max_width=265),
        icon=icon
    ).add_to(my_map)

sorted_students = student_contributions(locations)

ranking_html = "<h4 style='font-family:Arial, sans-serif; color:#2C3E50; text-align:center;'>Ranking of students by impact</h4><ul style='list-style-type:none; padding:0;'>"
for i, (student, impact) in enumerate(sorted_students, start=1):
    ranking_html += f"<li style='padding:10px 0; border-bottom:1px solid #ccc;'><strong>{i}. {student}</strong>: <span style='color:#27AE60;'>{impact} pt</span></li>"
ranking_html += "</ul>"

sidebar_html = f"""
<div id="mySidebar" style="position: fixed; top: 0; right: -300px; width: 300px; height: 100%; padding: 20px; background-color: #f9f9f9; border-left: 3px solid #2980B9; box-shadow: -2px 0 10px rgba(0,0,0,0.1); z-index: 1000; transition: 0.5s; overflow-y: auto; border-radius: 10px 0 0 10px;">
    <a href="javascript:void(0)" style="text-decoration:none; font-size:30px; position:absolute;top:10px;left:15px;color:#E74C3C;" onclick="closeSidebar()">×</a>
    {ranking_html}
</div>
<div id="openButton" style="position:fixed;top:10px;right:10px;z-index:1001;">
    <button onclick="openSidebar()" style="padding:10px 15px;background-color:#2980B9;border:none;border-radius:5px;color:white;font-weight:bold;cursor:pointer;box-shadow:0 4px 6px rgba(0,0,0,0.1);">Show Ranking</button>
</div>
<script>
function openSidebar() {{
    document.getElementById('mySidebar').style.right = '0';
    document.getElementById('openButton').style.display = 'none';
}}
function closeSidebar() {{
    document.getElementById('mySidebar').style.right = '-300px';
    document.getElementById('openButton').style.display = 'block';
}}
</script>
"""

my_map.get_root().html.add_child(folium.Element(sidebar_html))
my_map.save("custom_icons_map.html")
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ### Example of how the user could see real time data through the api of opeWeather

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Ejemplo visualización de datos**

# %%
import pandas as pd
import numpy as np

# Número de personas y registros por persona
n_personas = 20
n_registros_por_persona = 50

# Listado de nombres ficticios para las personas
nombres = [
    'Inés Sánchez', 'José Martínez', 'Carmen Rodríguez', 'Antonio Sánchez', 'Lucía Fernández',
    'María Gómez', 'Francisco García', 'Laura Jiménez', 'Javier López', 'Raquel Torres',
    'David Moreno', 'Beatriz Ruiz', 'Daniel Pérez', 'Marta Romero', 'Juan Torres',
    'Alicia Medina', 'Andrés Molina', 'Carlos Navarro', 'Pilar Suárez', 'Sofía González'
]

# Crear un DataFrame vacío
data = []

# Fecha de inicio
start_date = pd.to_datetime("2023-01-01")

# Generar registros para cada persona
for nombre in nombres:
    # Valores iniciales para suavizar cambios entre registros
    temp_base = 10  # Base inicial más baja para temperatura
    humedad_base = 80  # Base inicial más alta para humedad
    aqi_base = 1.5  # Base inicial para AQI PM2.5

    # Variaciones estacionales
    for i in range(n_registros_por_persona):
        current_date = start_date + pd.DateOffset(weeks=i)
        month = current_date.month

        # Simular variación estacional de la temperatura
        if month in [12, 1, 2]:  # Invierno
            seasonal_temp_variation = np.random.uniform(-5, 5)
        elif month in [3, 4, 5]:  # Primavera
            seasonal_temp_variation = np.random.uniform(0, 10)
        elif month in [6, 7, 8]:  # Verano
            seasonal_temp_variation = np.random.uniform(15, 25)
        elif month in [9, 10, 11]:  # Otoño
            seasonal_temp_variation = np.random.uniform(5, 15)

        temperatura = temp_base + seasonal_temp_variation
        humedad = np.clip(humedad_base - 0.3 * seasonal_temp_variation, 20, 100)  # Ajuste inverso con la temperatura

        # AQI PM2.5 varía con la temperatura y la lluvia potencial
        lluvia = max(0, np.random.normal(2, 1))
        aqi_variation = np.random.uniform(-0.1, 0.1) + 0.05 * lluvia  # Aumenta ligeramente con más lluvia
        aqi_pm2_5 = np.clip(aqi_base + aqi_variation - 0.01 * temperatura, 0.5, 2.5)  # Menor en temperaturas altas

        registro = {
            'Nombre': nombre,
            'Fecha': current_date,
            'AQI_PM2.5 (µg/m³)': aqi_pm2_5,
            'Lluvia (mm/h)': lluvia,
            'Temperatura (°C)': temperatura,
            'Humedad (%)': humedad,
            'Nubosidad (%)': np.random.uniform(0, 100),
            'Riego Semanal (puntos)': np.random.randint(5, 11),
            'Puntuación': np.random.randint(0, 11)  # Corrección aquí para incluir 0 en el rango
        }
        data.append(registro)

# Crear DataFrame a partir de los registros generados
df_grande = pd.DataFrame(data)

# Mostrar los primeros registros
print(df_grande.head(20))
# Out:
#           Nombre      Fecha  AQI_PM2.5 (µg/m³)  Lluvia (mm/h)  \
# 0   Inés Sánchez 2023-01-01           1.467836       2.691086
# 1   Inés Sánchez 2023-01-08           1.454271       3.134508
# 2   Inés Sánchez 2023-01-15           1.493828       2.965494
# 3   Inés Sánchez 2023-01-22           1.544633       2.287874
# 4   Inés Sánchez 2023-01-29           1.457949       1.514146
# 5   Inés Sánchez 2023-02-05           1.636274       3.507116
# 6   Inés Sánchez 2023-02-12           1.629628       3.495956
# 7   Inés Sánchez 2023-02-19           1.502933       1.565983
# 8   Inés Sánchez 2023-02-26           1.509478       3.483903
# 9   Inés Sánchez 2023-03-05           1.428821       0.669327
# 10  Inés Sánchez 2023-03-12           1.479862       3.785453
# 11  Inés Sánchez 2023-03-19           1.491215       2.513777
# 12  Inés Sánchez 2023-03-26           1.477499       2.410756
# 13  Inés Sánchez 2023-04-02           1.540367       2.732360
# ...

# %%
df_grande.to_csv('simulacion_datos_historicos.csv', index=False)

# %% [markdown]
# ### **We maintain a historical record of your plant's data, allowing us to track the weather conditions it has experienced, the number of times you've watered it, and the score associated with its care. This enables us to not only access real-time data but also analyze historical trends for a deeper understanding of your plant's health and care patterns.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from scipy.ndimage import gaussian_filter1d

# Set seaborn style
sns.set(style="whitegrid")

# Filter data for a specific person (e.g., 'Inés Sánchez')
person = 'Inés Sánchez'
df_person = df_grande[df_grande['Nombre'] == person]

# Create figure and axes
fig, axs = plt.subplots(3, 2, figsize=(14, 14), dpi=80)
fig.suptitle(f'Evolution of Conditions for {person}', fontsize=16, fontweight='bold')

# Format dates for better visualization
df_person['Fecha'] = pd.to_datetime(df_person['Fecha'])

# Smooth lines for better aesthetic visualization
def smooth_line(series):
    return gaussian_filter1d(series, sigma=2)

# AQI PM2.5
sns.lineplot(x='Fecha', y=smooth_line(df_person['AQI_PM2.5 (µg/m³)']), data=df_person, ax=axs[0, 0], color='green', marker='o')
axs[0, 0].set_title('Air Quality (AQI PM2.5)', fontsize=14)
axs[0, 0].set_ylabel('µg/m³')

# Rain
sns.lineplot(x='Fecha', y=smooth_line(df_person['Lluvia (mm/h)']), data=df_person, ax=axs[0, 1], color='blue', marker='o')
axs[0, 1].set_title('Rain', fontsize=14)
axs[0, 1].set_ylabel('mm/h')

# Temperature
sns.lineplot(x='Fecha', y=smooth_line(df_person['Temperatura (°C)']), data=df_person, ax=axs[1, 0], color='red', marker='o')
axs[1, 0].set_title('Temperature', fontsize=14)
axs[1, 0].set_ylabel('°C')

# Humidity
sns.lineplot(x='Fecha', y=smooth_line(df_person['Humedad (%)']), data=df_person, ax=axs[1, 1], color='purple', marker='o')
axs[1, 1].set_title('Humidity', fontsize=14)
axs[1, 1].set_ylabel('%')

# Weekly Watering
sns.lineplot(x='Fecha', y=smooth_line(df_person['Riego Semanal (puntos)']), data=df_person, ax=axs[2, 0], color='orange', marker='o')
axs[2, 0].set_title('Weekly Watering', fontsize=14)
axs[2, 0].set_ylabel('Points')

# Score
sns.lineplot(x='Fecha', y=smooth_line(df_person['Puntuación']), data=df_person, ax=axs[2, 1], color='brown', marker='x')
axs[2, 1].set_title('Score', fontsize=14)
axs[2, 1].set_ylabel('Points')
axs[2, 1].set_ylim(0, 10)  # Set Y-axis range from 0 to 10

# Adjust layout and display
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# <ipython-input-39-730cbd006960>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_person['Fecha'] = pd.to_datetime(df_person['Fecha'])
